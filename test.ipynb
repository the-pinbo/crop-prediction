# %%
from utils.pred_crop import get_prediction,predict_crop
from utils.pred_temp import *
import pandas as pd
import random

# %%
STATE = 'KERALA'
DISTRICT = 'PATHANAMTHITTA'
MONTH = 'APR'

# %%
crops = pd.read_csv('./data/district wise rainfall normal.csv')
crops
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
get_temperature(STATE, DISTRICT, MONTH)
# Out:
# 184.9

# %%
df = pd.read_csv('./data/Crop_recommendation.csv')
features = df.iloc[:, :-1].values
labels = df.iloc[:, -1].values

# %%
for i in range(10):
    x = features[random.randint(0,features.shape[0])]
    # print(x)
    print(get_prediction(x))
    # print(predict_crop(*x))
# Out:
# /home/pinbo/Documents/tri-nit-ml3/model/net.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# ['rice']
# ['apple']
# ['blackgram']
# ['lentil']
# ['cotton']
# ['lentil']
# ['jute']
# ['chickpea']
# ['kidneybeans']
# ['chickpea']
# /home/pinbo/Documents/tri-nit-ml3/model/net.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /home/pinbo/Documents/tri-nit-ml3/model/net.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# /home/pinbo/Documents/tri-nit-ml3/model/net.py:18: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# ...
